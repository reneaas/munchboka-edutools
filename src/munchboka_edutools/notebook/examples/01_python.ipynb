# %% [markdown]
# # Bli kjent med Python
#
# Kjør en celle med **Shift + Enter**. Endre tallene og prøv igjen!

# %%
navn = "Ada"
alder = 16
print(f"Hei, {navn}!")

# %%
print(f"Om fem år er du {alder + 5} år.")

# %% [markdown]
# ## Din tur
#
# Lag en variabel for prisen på en vare. Regn ut prisen etter 20 % rabatt.

# %%
pris = 250
